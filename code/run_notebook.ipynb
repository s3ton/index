# %%
from abc import ABC, abstractmethod
import pandas as pd
import numpy as np
import yfinance as yf
import plotly.graph_objects as go  
import json
from classi_strategia import VolMktCapStrategy, RebalancedMarketCapStrategy, MarketCapThresholdStrategy, EqualWeightThresholdStrategy, GlobalMarketAnalytics

# diagnostics: show which Python/kernel is running (useful when kernel errors occur)
import sys, os
print("Python executable:", sys.executable)
print("Python version:", sys.version)
print("Notebook cwd:", os.getcwd())
# Out:
# Python executable: /Users/teamfinance1/index/code/fedenv/bin/python
# Python version: 3.12.1 (v3.12.1:2305ca5144, Dec  7 2023, 17:23:38) [Clang 13.0.0 (clang-1300.0.29.30)]
# Notebook cwd: /Users/teamfinance1/index/code

# %% [markdown]
# IMPORTO I TICKER PER LA COSTRUZIONE DEGLI INDICI

# %%
# ticker
with open("ticker_yf.json", "r") as f:
    dati_caricati = json.load(f)

conio_coin = dati_caricati['conio_coin']
tech = dati_caricati['tech']
defi = dati_caricati['defi']
pagamenti = dati_caricati['pagamenti']

# %% [markdown]
# STRATEGIA VOL/MKTCAP

# %%
strategy_volmktcap = VolMktCapStrategy()

strategy_volmktcap.import_data(assets=conio_coin, timeframe="5y")

strategy_volmktcap.run_strategy()

strategy_volmktcap.plot_results(title="Volume/Market_Cap Strategy vs BTC-USD",
                                save_json_dir="../charts/VolMktCap_TH")
# Out:
# Inizio download dati per il periodo '5y'...
#
# Avvio backtest con ribilanciamento ogni 180 giorni.
# Periodo di warm-up (180 giorni): dal 2021-03-09 al 2021-09-04
# Asset iniziali validi selezionati: ['BTC-USD', 'ETH-USD', 'ADA-USD', 'SOL-USD', 'XRP-USD']
# Valore iniziale del portafoglio impostato al prezzo di BTC-USD in data 2021-09-05: 51753.41 USD
# Backtest completato con successo su tutto il periodo storico disponibile.
#                             Strategia  BTC-USD
# Ritorno Annualizzato (%)       18.53%   20.18%
# Volatilità Annualizzata (%)    70.68%   53.34%
# Sharpe Ratio                     0.26     0.38
# Max Drawdown (%)              -84.13%  -76.63%

# %% [markdown]
# INDICE MKT CAP CON LE 5 COIN PIù CAPITALIZZATE

# %%
strategy_5mktcap = RebalancedMarketCapStrategy()

strategy_5mktcap.import_data(assets= conio_coin, timeframe="5y")

strategy_5mktcap.run_strategy()

strategy_5mktcap.plot_results(title="Top 5 Market Cap Index vs BTC-USD",
                              save_json_dir="../charts/Top5MktCap")

strategy_5mktcap.plot_weights()
# Out:
# Inizio download dati per il periodo '5y'...
#
# Avvio backtest: Top Dinamica con ribilanciamento (ogni 180 giorni)...
# Valore iniziale del portafoglio impostato al prezzo di BTC-USD in data 2021-03-09: 54824.12 USD
# Backtest completato. Composizione FINALE del portafoglio al 2026-03-09:
# - BTC-USD: 77.97% (Mkt Cap: 1,339,833,077,755)
# - ETH-USD: 13.63% (Mkt Cap: 234,217,563,663)
# - XRP-USD: 4.87% (Mkt Cap: 83,760,835,611)
# - SOL-USD: 2.63% (Mkt Cap: 45,238,102,476)
# - DOGE-USD: 0.90% (Mkt Cap: 15,391,696,070)
#                             Strategia  BTC-USD
# Ritorno Annualizzato (%)       20.45%   20.15%
# Volatilità Annualizzata (%)    60.20%   56.42%
# Sharpe Ratio                     0.34     0.36
# Max Drawdown (%)              -78.58%  -76.63%

# %% [markdown]
# INDICE MKT CAP CON THRESHOLD

# %%
strategy_threshold = MarketCapThresholdStrategy()

strategy_threshold.import_data(assets=tech, timeframe="5y")

strategy_threshold.run_strategy()

strategy_threshold.plot_results(title="Tech crypto market index",
                                save_json_dir="../charts/TechMktCap_TH")
# Out:
# Inizio download dati per il periodo '5y'...
#
# BTC-USD non presente nel dizionario. Avvio download in un df separato...
# Benchmark BTC-USD completato con successo.
#
#
# Avvio backtest: ribilanciamento ogni 180 giorni, soglia MktCap 1,000,000,000.
# Recupero il prezzo storico di BTC-USD per impostare il capitale iniziale...
# Valore iniziale del portafoglio impostato al prezzo di BTC-USD in data 2021-03-09: 54824.12 USD
# Backtest completato. Composizione finale al 2026-03-09:
# - ETH-USD: 77.28% (Mkt Cap: 234,217,563,663)
# - SOL-USD: 14.93% (Mkt Cap: 45,238,102,476)
# - ADA-USD: 3.04% (Mkt Cap: 9,221,590,083)
# - AVAX-USD: 1.23% (Mkt Cap: 3,726,278,605)
# - DOT-USD: 0.69% (Mkt Cap: 2,098,815,760)
# - NEAR-USD: 0.41% (Mkt Cap: 1,239,083,448)
# - SUI20947-USD: 1.15% (Mkt Cap: 3,479,523,497)
# - HBAR-USD: 1.27% (Mkt Cap: 3,853,181,718)
#                             Strategia  BTC-USD
# Ritorno Annualizzato (%)       24.05%   20.15%
# Volatilità Annualizzata (%)    76.34%   56.42%
# Sharpe Ratio                     0.32     0.36
# Max Drawdown (%)              -82.34%  -76.63%

# %%
strategy_threshold = MarketCapThresholdStrategy()

strategy_threshold.import_data(assets=defi, timeframe="5y")

strategy_threshold.run_strategy()

strategy_threshold.plot_results(title="Defi crypto market index",
                                save_json_dir="../charts/DefiMktCap_TH")
# Out:
# Inizio download dati per il periodo '5y'...
#
# BTC-USD non presente nel dizionario. Avvio download in un df separato...
# Benchmark BTC-USD completato con successo.
#
#
# Avvio backtest: ribilanciamento ogni 180 giorni, soglia MktCap 1,000,000,000.
# Recupero il prezzo storico di BTC-USD per impostare il capitale iniziale...
# Valore iniziale del portafoglio impostato al prezzo di BTC-USD in data 2021-03-09: 54824.12 USD
# Backtest completato. Composizione finale al 2026-03-09:
# - LINK-USD: 47.65% (Mkt Cap: 5,885,436,076)
# - UNI7083-USD: 17.23% (Mkt Cap: 2,127,508,452)
# - SKY33038-USD: 12.26% (Mkt Cap: 1,514,500,608)
# - AAVE-USD: 13.37% (Mkt Cap: 1,650,855,316)
# - ONDO-USD: 9.50% (Mkt Cap: 1,172,953,544)
#                             Strategia  BTC-USD
# Ritorno Annualizzato (%)       11.09%   20.15%
# Volatilità Annualizzata (%)    91.78%   56.42%
# Sharpe Ratio                     0.12     0.36
# Max Drawdown (%)              -89.81%  -76.63%

# %%
strategy_threshold = MarketCapThresholdStrategy()

strategy_threshold.import_data(assets=pagamenti, timeframe="5y")

strategy_threshold.run_strategy()

strategy_threshold.plot_results(title="Pagamenti crypto market index",
                                save_json_dir="../charts/PagamentiMktCap_TH")
# Out:
# Inizio download dati per il periodo '5y'...
#
# Avvio backtest: ribilanciamento ogni 180 giorni, soglia MktCap 1,000,000,000.
# Valore iniziale del portafoglio impostato al prezzo di BTC-USD in data 2021-03-09: 54824.12 USD
# Backtest completato. Composizione finale al 2026-03-09:
# - BTC-USD: 93.78% (Mkt Cap: 1,339,833,077,755)
# - XRP-USD: 5.86% (Mkt Cap: 83,760,835,611)
# - XLM-USD: 0.36% (Mkt Cap: 5,097,222,365)
#                             Strategia  BTC-USD
# Ritorno Annualizzato (%)       21.03%   20.15%
# Volatilità Annualizzata (%)    57.12%   56.42%
# Sharpe Ratio                     0.37     0.36
# Max Drawdown (%)              -76.37%  -76.63%

# %% [markdown]
# INDICE PAGAMENTI EQUAL WEIGHT

# %%
strategy_equal_weight = EqualWeightThresholdStrategy()

strategy_equal_weight.import_data(assets=pagamenti, timeframe="5y")

strategy_equal_weight.run_strategy()

strategy_equal_weight.plot_results(title="E.W. Pagamenti Index vs BTC-USD", 
                                    save_json_dir="../charts/PagamentiEW_TH")
# Out:
# Inizio download dati per il periodo '5y'...
#
# Avvio backtest: ribilanciamento ogni 180 giorni, soglia MktCap 1,000,000,000. Metodo: Equal Weight.
# Valore iniziale del portafoglio impostato al prezzo di BTC-USD in data 2021-03-09: 54824.12
# Backtest completato. Composizione finale al 2026-03-09:
# - BTC-USD: 33.33% (Mkt Cap reale: 1,339,833,077,755)
# - XRP-USD: 33.33% (Mkt Cap reale: 83,760,835,611)
# - XLM-USD: 33.33% (Mkt Cap reale: 5,097,222,365)
#                             Strategia  BTC-USD
# Ritorno Annualizzato (%)       37.21%   20.15%
# Volatilità Annualizzata (%)    76.98%   56.42%
# Sharpe Ratio                     0.48     0.36
# Max Drawdown (%)              -81.73%  -76.63%

# %%
# 1. Definisci l'universo
assets = ['BTC-USD', 'ETH-USD', 'SOL-USD', 'UNI7083-USD'] # Ecc ecc..

# 2. Crea l'oggetto per le analisi globali
market_analytics = GlobalMarketAnalytics()
market_analytics.import_data(assets, timeframe="1y")

# 3. Genera e salva i JSON
market_analytics.generate_analytics_charts(save_dir="../charts/market_analytics")
# Out:
# Inizio download dati per il periodo '1y'...
#
# Generazione grafici Market Analytics in '../charts/market_analytics'...
#  - btc_dominance.json salvato.
#  - market_volume.json salvato.
#  - fear_and_greed.json salvato.
#  - correlation_heatmap.json salvato.

# %%
if __name__ == "__main__":


    market_analytics = GlobalMarketAnalytics()
    
    # Importiamo un range storico ampio (es. 2 anni) in modo da poter tagliare 
    # dinamicamente in base alle nostre necessità grafiche successive.
    market_analytics.import_data(conio_coin, timeframe="5y")

    # Genera i grafici scegliendo timeframe specifici e indipendenti!
    market_analytics.generate_analytics_charts(
        conio_coin=conio_coin, 
        save_dir="../charts/market_analytics",
        tf_dom='5y',       # Dominance dell'ultimo anno
        tf_vol='1y',  # Correlazione calcolata sugli ultimi 6 mesi
        show_figs=True
    )
# Out:
# Inizio download dati per il periodo '5y'...
#
# Generazione grafici Market Analytics in '../charts/market_analytics'...
#  - btc_dominance.json (5y) salvato.
#  - market_volume.json (1y) salvato.
#  - fear_and_greed.json salvato.
#  - correlation_heatmap.json salvato.
