# %%
from abc import ABC, abstractmethod
import pandas as pd
import numpy as np
import yfinance as yf
import plotly.graph_objects as go  
import json
from classi_strategia import VolMktCapStrategy, RebalancedMarketCapStrategy

# %%
# ticker
with open("ticker_yf.json", "r") as f:
    dati_caricati = json.load(f)

conio_coin = dati_caricati['conio_coin']
tech = dati_caricati['tech']

# %%
import importlib
import classi_strategia
importlib.reload(classi_strategia)
from classi_strategia import VolMktCapStrategy, RebalancedMarketCapStrategy
print("Modulo ricaricato con successo")

# %%
# 1. Inizializziamo la strategia figlia con un capitale di partenza
strategy = VolMktCapStrategy(initial_value=10000.0)

# 2. Importiamo i dati utilizzando il caching
# use_cache=True: carica dalla cache se disponibile, altrimenti scarica e salva
# refresh_cache=False: usa la cache esistente (False di default)
strategy.import_data(assets=conio_coin, timeframe="5y", use_cache=True, refresh_cache=False)

# 3. Eseguiamo il backtest (es. ribilanciamento ogni 30 giorni)
strategy.run_strategy(rebalance_freq_days=30)

# 4. Calcoliamo e stampiamo le statistiche
print("\n--- Statistiche di Performance ---")
stats_df = strategy.calculate_stats()
print(stats_df)

# 5. Mostriamo i grafici
strategy.plot_results()
strategy.plot_weights()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 7
#       2 strategy = VolMktCapStrategy(initial_value=10000.0)
#       4 # 2. Importiamo i dati utilizzando il caching
#       5 # use_cache=True: carica dalla cache se disponibile, altrimenti scarica e salva
#       6 # refresh_cache=False: usa la cache esistente (False di default)
# ----> 7 strategy.import_data(assets=conio_coin, timeframe="5y", use_cache=True, refresh_cache=False)
#       9 # 3. Eseguiamo il backtest (es. ribilanciamento ogni 30 giorni)
#      10 strategy.run_strategy(rebalance_freq_days=30)
#
# TypeError: import_data() got an unexpected keyword argument 'use_cache'

# %%
# 1. Inizializziamo la strategia figlia con un capitale di partenza
strategy = RebalancedMarketCapStrategy(initial_value=10000.0)

# 2. Importiamo i dati utilizzando il caching
# use_cache=True: carica dalla cache se disponibile, altrimenti scarica e salva
# refresh_cache=False: usa la cache esistente (False di default)
strategy.import_data(assets=dati_caricati['tech'], timeframe="5y", use_cache=True, refresh_cache=False)

# 3. Eseguiamo il backtest (es. ribilanciamento ogni 30 giorni)
strategy.run_strategy(rebalance_freq_days=30)

# 4. Calcoliamo e stampiamo le statistiche
print("\n--- Statistiche di Performance ---")
stats_df = strategy.calculate_stats()
print(stats_df)

# 5. Mostriamo il grafico
strategy.plot_results()
# Out:
# Inizio download dati per il periodo '5y'...
#
# BTC-USD non presente nel dizionario. Avvio download in un df separato...
# Benchmark BTC-USD completato con successo.
#
#
# Avvio backtest: Top 10 Dinamica con ribilanciamento (frequenza: Q)...
# Backtest completato. Composizione FINALE del portafoglio al 2026-02-26:
# - ETH-USD: 77.28% (Mkt Cap: 358,098,556,243)
# - SOL-USD: 15.28% (Mkt Cap: 70,800,590,146)
# - ADA-USD: 2.59% (Mkt Cap: 12,006,554,963)
# - SUI20947-USD: 1.16% (Mkt Cap: 5,394,645,291)
# - AVAX-USD: 1.15% (Mkt Cap: 5,312,904,374)
# - HBAR-USD: 0.99% (Mkt Cap: 4,567,436,278)
# - DOT-USD: 0.64% (Mkt Cap: 2,986,645,013)
# - NEAR-USD: 0.42% (Mkt Cap: 1,948,759,164)
# - APT21794-USD: 0.28% (Mkt Cap: 1,295,900,379)
# - ALGO-USD: 0.21% (Mkt Cap: 979,787,498)
#
# --- Statistiche di Performance ---
#                              Strategia  BTC-USD
# Ritorno Annualizzato (%)       29.3222  23.5680
# Volatilità Annualizzata (%)    76.4724  56.5757
# ...
